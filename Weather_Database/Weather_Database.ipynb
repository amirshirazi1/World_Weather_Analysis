# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | haines junction
# Processing Record 4 of Set 1 | benghazi
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 1 | phangnga
# Processing Record 15 of Set 1 | show low
# Processing Record 16 of Set 1 | namatanai
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | sabang
# Processing Record 25 of Set 1 | bengkulu
# Processing Record 26 of Set 1 | san patricio
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | lebu
# Processing Record 31 of Set 1 | chokurdakh
# Processing Record 32 of Set 1 | parabel
# Processing Record 33 of Set 1 | borovskoy
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | yuzhno-kurilsk
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | port blair
# Processing Record 41 of Set 1 | mezen
# Processing Record 42 of Set 1 | namibe
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | phanom sarakham
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | vestmanna
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | washougal
# Processing Record 1 of Set 2 | puerto escondido
# Processing Record 2 of Set 2 | sao miguel do araguaia
# Processing Record 3 of Set 2 | port hawkesbury
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | bahia honda
# Processing Record 6 of Set 2 | beisfjord
# Processing Record 7 of Set 2 | pangnirtung
# Processing Record 8 of Set 2 | miles city
# Processing Record 9 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | caravelas
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | cam pha
# City not found. Skipping...
# Processing Record 17 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 18 of Set 2 | nhulunbuy
# Processing Record 19 of Set 2 | lichtenstein
# Processing Record 20 of Set 2 | palmer
# Processing Record 21 of Set 2 | dzhebariki-khaya
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | castro
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | hamilton
# Processing Record 26 of Set 2 | along
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | henties bay
# Processing Record 30 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 2 | sukhoverkovo
# City not found. Skipping...
# Processing Record 32 of Set 2 | burnie
# Processing Record 33 of Set 2 | marystown
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 2 | punta alta
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | tarancon
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | salinas
# Processing Record 43 of Set 2 | port lincoln
# Processing Record 44 of Set 2 | nome
# Processing Record 45 of Set 2 | khani
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | buchanan
# Processing Record 49 of Set 2 | deniliquin
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | kavieng
# Processing Record 2 of Set 3 | poum
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | luau
# Processing Record 6 of Set 3 | aripuana
# Processing Record 7 of Set 3 | portland
# Processing Record 8 of Set 3 | deputatskiy
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | palimbang
# Processing Record 11 of Set 3 | kayerkan
# Processing Record 12 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 13 of Set 3 | ancud
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | kamaishi
# Processing Record 16 of Set 3 | talnakh
# Processing Record 17 of Set 3 | omsukchan
# Processing Record 18 of Set 3 | laguna
# Processing Record 19 of Set 3 | dawei
# Processing Record 20 of Set 3 | nanortalik
# Processing Record 21 of Set 3 | luwero
# Processing Record 22 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 3 | iwaki
# Processing Record 24 of Set 3 | hovd
# Processing Record 25 of Set 3 | zhuhai
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | bilibino
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | sri aman
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | cairns
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | cayenne
# Processing Record 36 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | richmond hill
# Processing Record 39 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 3 | kano
# Processing Record 41 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 42 of Set 3 | kuryk
# Processing Record 43 of Set 3 | qostanay
# Processing Record 44 of Set 3 | wuda
# Processing Record 45 of Set 3 | dori
# Processing Record 46 of Set 3 | tiznit
# Processing Record 47 of Set 3 | iralaya
# Processing Record 48 of Set 3 | kodiak
# Processing Record 49 of Set 3 | alugan
# Processing Record 50 of Set 3 | verkhnevilyuysk
# Processing Record 1 of Set 4 | sabya
# Processing Record 2 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 3 of Set 4 | zheleznodorozhnyy
# Processing Record 4 of Set 4 | cimislia
# Processing Record 5 of Set 4 | kathmandu
# Processing Record 6 of Set 4 | coihaique
# Processing Record 7 of Set 4 | khagaria
# Processing Record 8 of Set 4 | bubaque
# Processing Record 9 of Set 4 | bilma
# Processing Record 10 of Set 4 | saint-pierre
# Processing Record 11 of Set 4 | udachnyy
# Processing Record 12 of Set 4 | dondo
# Processing Record 13 of Set 4 | rocha
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | broken hill
# Processing Record 16 of Set 4 | quipile
# Processing Record 17 of Set 4 | bako
# Processing Record 18 of Set 4 | marawi
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | rafaela
# Processing Record 21 of Set 4 | hokitika
# Processing Record 22 of Set 4 | yurga
# Processing Record 23 of Set 4 | gat
# Processing Record 24 of Set 4 | suntar
# Processing Record 25 of Set 4 | morehead
# Processing Record 26 of Set 4 | aksarka
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | nong kung si
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | oktyabrskiy
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | kamenka
# Processing Record 34 of Set 4 | khowst
# Processing Record 35 of Set 4 | kjopsvik
# Processing Record 36 of Set 4 | bathsheba
# Processing Record 37 of Set 4 | hithadhoo
# Processing Record 38 of Set 4 | archidona
# Processing Record 39 of Set 4 | kerman
# Processing Record 40 of Set 4 | erdaojiang
# Processing Record 41 of Set 4 | almaznyy
# Processing Record 42 of Set 4 | plouzane
# Processing Record 43 of Set 4 | kahului
# Processing Record 44 of Set 4 | wanning
# Processing Record 45 of Set 4 | vendome
# Processing Record 46 of Set 4 | vao
# Processing Record 47 of Set 4 | hasaki
# Processing Record 48 of Set 4 | maloyaz
# City not found. Skipping...
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | fairbanks
# Processing Record 1 of Set 5 | faya
# Processing Record 2 of Set 5 | flinders
# Processing Record 3 of Set 5 | kalaleh
# Processing Record 4 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 5 | meulaboh
# Processing Record 6 of Set 5 | mayo
# Processing Record 7 of Set 5 | korla
# Processing Record 8 of Set 5 | sikonge
# Processing Record 9 of Set 5 | chara
# Processing Record 10 of Set 5 | brokopondo
# Processing Record 11 of Set 5 | ponta do sol
# Processing Record 12 of Set 5 | pleszew
# Processing Record 13 of Set 5 | margate
# Processing Record 14 of Set 5 | codrington
# Processing Record 15 of Set 5 | le port
# Processing Record 16 of Set 5 | macusani
# Processing Record 17 of Set 5 | buin
# Processing Record 18 of Set 5 | kapit
# Processing Record 19 of Set 5 | camopi
# Processing Record 20 of Set 5 | columbia
# Processing Record 21 of Set 5 | nouadhibou
# Processing Record 22 of Set 5 | kashi
# Processing Record 23 of Set 5 | anadyr
# Processing Record 24 of Set 5 | alyangula
# Processing Record 25 of Set 5 | atar
# Processing Record 26 of Set 5 | bermejo
# Processing Record 27 of Set 5 | road town
# Processing Record 28 of Set 5 | changji
# Processing Record 29 of Set 5 | plettenberg bay
# Processing Record 30 of Set 5 | vallenar
# Processing Record 31 of Set 5 | bulri
# Processing Record 32 of Set 5 | beringovskiy
# Processing Record 33 of Set 5 | gizo
# Processing Record 34 of Set 5 | petapa
# Processing Record 35 of Set 5 | najran
# Processing Record 36 of Set 5 | yerbogachen
# Processing Record 37 of Set 5 | coolum beach
# Processing Record 38 of Set 5 | kintampo
# Processing Record 39 of Set 5 | upata
# Processing Record 40 of Set 5 | acarau
# Processing Record 41 of Set 5 | kurilsk
# Processing Record 42 of Set 5 | labuan
# Processing Record 43 of Set 5 | matara
# Processing Record 44 of Set 5 | luanda
# Processing Record 45 of Set 5 | neuquen
# Processing Record 46 of Set 5 | hervey bay
# Processing Record 47 of Set 5 | celestun
# Processing Record 48 of Set 5 | butaritari
# Processing Record 49 of Set 5 | miraflores
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | qaanaaq
# Processing Record 2 of Set 6 | ilulissat
# Processing Record 3 of Set 6 | mega
# Processing Record 4 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 6 | kikuchi
# Processing Record 6 of Set 6 | sindhnur
# Processing Record 7 of Set 6 | sohag
# Processing Record 8 of Set 6 | kaitangata
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | hofn
# Processing Record 13 of Set 6 | bonavista
# Processing Record 14 of Set 6 | khanpur
# Processing Record 15 of Set 6 | inta
# Processing Record 16 of Set 6 | okhotsk
# Processing Record 17 of Set 6 | agadir
# Processing Record 18 of Set 6 | maningrida
# Processing Record 19 of Set 6 | kinshasa
# Processing Record 20 of Set 6 | manokwari
# Processing Record 21 of Set 6 | rio grande
# Processing Record 22 of Set 6 | calubcub
# City not found. Skipping...
# Processing Record 23 of Set 6 | vanimo
# Processing Record 24 of Set 6 | comodoro rivadavia
# Processing Record 25 of Set 6 | pevek
# Processing Record 26 of Set 6 | khuzhir
# Processing Record 27 of Set 6 | belmonte
# Processing Record 28 of Set 6 | provideniya
# Processing Record 29 of Set 6 | shache
# Processing Record 30 of Set 6 | hermiston
# Processing Record 31 of Set 6 | richards bay
# Processing Record 32 of Set 6 | dongsheng
# Processing Record 33 of Set 6 | airai
# Processing Record 34 of Set 6 | mao
# Processing Record 35 of Set 6 | zheshart
# Processing Record 36 of Set 6 | yuzhou
# Processing Record 37 of Set 6 | hay river
# Processing Record 38 of Set 6 | porto novo
# Processing Record 39 of Set 6 | havre-saint-pierre
# Processing Record 40 of Set 6 | nabire
# Processing Record 41 of Set 6 | saint anthony
# Processing Record 42 of Set 6 | goma
# Processing Record 43 of Set 6 | valparaiso
# Processing Record 44 of Set 6 | lasa
# Processing Record 45 of Set 6 | chulakivka
# Processing Record 46 of Set 6 | loreto
# Processing Record 47 of Set 6 | muisne
# Processing Record 48 of Set 6 | fortuna
# Processing Record 49 of Set 6 | fare
# Processing Record 50 of Set 6 | saint george
# Processing Record 1 of Set 7 | quang ngai
# Processing Record 2 of Set 7 | gazanjyk
# Processing Record 3 of Set 7 | ayorou
# Processing Record 4 of Set 7 | prado
# Processing Record 5 of Set 7 | montepuez
# Processing Record 6 of Set 7 | cabo san lucas
# Processing Record 7 of Set 7 | bindura
# Processing Record 8 of Set 7 | mandalgovi
# Processing Record 9 of Set 7 | sines
# Processing Record 10 of Set 7 | eureka
# Processing Record 11 of Set 7 | naron
# Processing Record 12 of Set 7 | college
# Processing Record 13 of Set 7 | gambo
# Processing Record 14 of Set 7 | saint-georges
# Processing Record 15 of Set 7 | tuma
# Processing Record 16 of Set 7 | lufilufi
# Processing Record 17 of Set 7 | finschhafen
# Processing Record 18 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 7 | yatou
# Processing Record 20 of Set 7 | alberton
# Processing Record 21 of Set 7 | curanilahue
# Processing Record 22 of Set 7 | soto
# Processing Record 23 of Set 7 | berlevag
# Processing Record 24 of Set 7 | borba
# Processing Record 25 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | pangai
# Processing Record 28 of Set 7 | torbay
# Processing Record 29 of Set 7 | goderich
# Processing Record 30 of Set 7 | sisimiut
# Processing Record 31 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 7 | jizan
# Processing Record 34 of Set 7 | kondapalle
# Processing Record 35 of Set 7 | manzhouli
# Processing Record 36 of Set 7 | port hedland
# Processing Record 37 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 38 of Set 7 | tuatapere
# Processing Record 39 of Set 7 | pallasovka
# Processing Record 40 of Set 7 | asha
# Processing Record 41 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 42 of Set 7 | buckie
# Processing Record 43 of Set 7 | karlskoga
# Processing Record 44 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 45 of Set 7 | san jose
# Processing Record 46 of Set 7 | zharkent
# Processing Record 47 of Set 7 | arlit
# Processing Record 48 of Set 7 | nioro
# Processing Record 49 of Set 7 | dibombari
# Processing Record 50 of Set 7 | gualaceo
# Processing Record 1 of Set 8 | batagay
# Processing Record 2 of Set 8 | syava
# Processing Record 3 of Set 8 | kuhdasht
# Processing Record 4 of Set 8 | unye
# City not found. Skipping...
# Processing Record 5 of Set 8 | alofi
# Processing Record 6 of Set 8 | makat
# Processing Record 7 of Set 8 | ishigaki
# Processing Record 8 of Set 8 | sao joao da barra
# Processing Record 9 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 10 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 8 | saint-augustin
# Processing Record 12 of Set 8 | yakeshi
# Processing Record 13 of Set 8 | townsville
# Processing Record 14 of Set 8 | yulara
# Processing Record 15 of Set 8 | taoudenni
# Processing Record 16 of Set 8 | pacific grove
# Processing Record 17 of Set 8 | tommot
# Processing Record 18 of Set 8 | mayskiy
# Processing Record 19 of Set 8 | anloga
# Processing Record 20 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 8 | podgornoye
# Processing Record 22 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 8 | linares
# Processing Record 24 of Set 8 | leningradskiy
# Processing Record 25 of Set 8 | totness
# Processing Record 26 of Set 8 | obo
# Processing Record 27 of Set 8 | naze
# Processing Record 28 of Set 8 | gravdal
# Processing Record 29 of Set 8 | maniitsoq
# Processing Record 30 of Set 8 | chrastava
# Processing Record 31 of Set 8 | luganville
# Processing Record 32 of Set 8 | san rafael
# Processing Record 33 of Set 8 | lagos
# Processing Record 34 of Set 8 | sao jose da coroa grande
# Processing Record 35 of Set 8 | sola
# Processing Record 36 of Set 8 | yar-sale
# Processing Record 37 of Set 8 | san borja
# Processing Record 38 of Set 8 | san jose del guaviare
# Processing Record 39 of Set 8 | birin
# Processing Record 40 of Set 8 | wageningen
# Processing Record 41 of Set 8 | krasnoarmeysk
# Processing Record 42 of Set 8 | falavarjan
# Processing Record 43 of Set 8 | rahway
# Processing Record 44 of Set 8 | menomonie
# Processing Record 45 of Set 8 | pandan
# Processing Record 46 of Set 8 | albanel
# Processing Record 47 of Set 8 | khuzdar
# Processing Record 48 of Set 8 | hazorasp
# Processing Record 49 of Set 8 | kieta
# Processing Record 50 of Set 8 | phuket
# Processing Record 1 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 9 | takoradi
# Processing Record 3 of Set 9 | huaicheng
# Processing Record 4 of Set 9 | senneterre
# Processing Record 5 of Set 9 | esperance
# Processing Record 6 of Set 9 | narrabri
# Processing Record 7 of Set 9 | dudinka
# Processing Record 8 of Set 9 | dabat
# Processing Record 9 of Set 9 | taltal
# Processing Record 10 of Set 9 | bousse
# Processing Record 11 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 12 of Set 9 | sainte-marie
# Processing Record 13 of Set 9 | sorland
# Processing Record 14 of Set 9 | rodionovo-nesvetayskaya
# Processing Record 15 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 9 | ponta delgada
# Processing Record 17 of Set 9 | ormara
# Processing Record 18 of Set 9 | mount isa
# Processing Record 19 of Set 9 | araouane
# Processing Record 20 of Set 9 | coruripe
# Processing Record 21 of Set 9 | semlac
# Processing Record 22 of Set 9 | poli
# Processing Record 23 of Set 9 | zhuanghe
# Processing Record 24 of Set 9 | payo
# Processing Record 25 of Set 9 | hobyo
# Processing Record 26 of Set 9 | conceicao do araguaia
# Processing Record 27 of Set 9 | visnes
# Processing Record 28 of Set 9 | tekeli
# Processing Record 29 of Set 9 | augustow
# Processing Record 30 of Set 9 | muli
# Processing Record 31 of Set 9 | ramanuj ganj
# Processing Record 32 of Set 9 | pierreville
# Processing Record 33 of Set 9 | karla
# Processing Record 34 of Set 9 | mogadishu
# Processing Record 35 of Set 9 | begoro
# Processing Record 36 of Set 9 | barcelos
# Processing Record 37 of Set 9 | iquitos
# Processing Record 38 of Set 9 | montego bay
# Processing Record 39 of Set 9 | hami
# Processing Record 40 of Set 9 | algiers
# Processing Record 41 of Set 9 | douglas
# Processing Record 42 of Set 9 | ruian
# City not found. Skipping...
# Processing Record 43 of Set 9 | shenjiamen
# Processing Record 44 of Set 9 | chajul
# Processing Record 45 of Set 9 | lastoursville
# Processing Record 46 of Set 9 | high level
# Processing Record 47 of Set 9 | gaillac
# Processing Record 48 of Set 9 | san policarpo
# Processing Record 49 of Set 9 | westport
# Processing Record 50 of Set 9 | kangaatsiaq
# Processing Record 1 of Set 10 | biu
# Processing Record 2 of Set 10 | pljevlja
# Processing Record 3 of Set 10 | saint-francois
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | omboue
# Processing Record 6 of Set 10 | chapais
# Processing Record 7 of Set 10 | bay roberts
# Processing Record 8 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 9 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 10 | honiara
# Processing Record 11 of Set 10 | tawang
# Processing Record 12 of Set 10 | cascais
# Processing Record 13 of Set 10 | moron
# Processing Record 14 of Set 10 | vagur
# Processing Record 15 of Set 10 | kisangani
# Processing Record 16 of Set 10 | tromso
# Processing Record 17 of Set 10 | am timan
# Processing Record 18 of Set 10 | oranjemund
# Processing Record 19 of Set 10 | iqaluit
# Processing Record 20 of Set 10 | tiberias
# Processing Record 21 of Set 10 | wajir
# Processing Record 22 of Set 10 | salalah
# Processing Record 23 of Set 10 | noumea
# Processing Record 24 of Set 10 | praia
# Processing Record 25 of Set 10 | ust-maya
# Processing Record 26 of Set 10 | mahibadhoo
# Processing Record 27 of Set 10 | mayumba
# Processing Record 28 of Set 10 | zyryanka
# Processing Record 29 of Set 10 | vila velha
# Processing Record 30 of Set 10 | half moon bay
# Processing Record 31 of Set 10 | praia da vitoria
# Processing Record 32 of Set 10 | koutsouras
# Processing Record 33 of Set 10 | sayyan
# Processing Record 34 of Set 10 | myingyan
# Processing Record 35 of Set 10 | odweyne
# Processing Record 36 of Set 10 | isla mujeres
# Processing Record 37 of Set 10 | mizdah
# Processing Record 38 of Set 10 | kapoeta
# Processing Record 39 of Set 10 | paamiut
# Processing Record 40 of Set 10 | lushunkou
# City not found. Skipping...
# Processing Record 41 of Set 10 | aswan
# Processing Record 42 of Set 10 | bayanday
# Processing Record 43 of Set 10 | sabha
# Processing Record 44 of Set 10 | sao filipe
# Processing Record 45 of Set 10 | villanueva de cordoba
# Processing Record 46 of Set 10 | vostok
# Processing Record 47 of Set 10 | wairoa
# Processing Record 48 of Set 10 | banda aceh
# Processing Record 49 of Set 10 | sioux lookout
# Processing Record 50 of Set 10 | cidreira
# Processing Record 1 of Set 11 | ust-koksa
# Processing Record 2 of Set 11 | ginir
# Processing Record 3 of Set 11 | kichera
# Processing Record 4 of Set 11 | tombouctou
# Processing Record 5 of Set 11 | griffith
# Processing Record 6 of Set 11 | binika
# Processing Record 7 of Set 11 | grenfell
# Processing Record 8 of Set 11 | san pedro
# Processing Record 9 of Set 11 | chaman
# Processing Record 10 of Set 11 | kalisz
# Processing Record 11 of Set 11 | awbari
# Processing Record 12 of Set 11 | sur
# Processing Record 13 of Set 11 | itarema
# Processing Record 14 of Set 11 | norton shores
# Processing Record 15 of Set 11 | antofagasta
# Processing Record 16 of Set 11 | emba
# Processing Record 17 of Set 11 | barhi
# Processing Record 18 of Set 11 | salcininkai
# Processing Record 19 of Set 11 | sterling
# Processing Record 20 of Set 11 | tomatlan
# Processing Record 21 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 22 of Set 11 | kamyshevatskaya
# Processing Record 23 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 24 of Set 11 | bam
# Processing Record 25 of Set 11 | lompoc
# Processing Record 26 of Set 11 | moyale
# Processing Record 27 of Set 11 | banjar
# Processing Record 28 of Set 11 | bakel
# Processing Record 29 of Set 11 | komsomolskiy
# Processing Record 30 of Set 11 | kizema
# Processing Record 31 of Set 11 | tosya
# Processing Record 32 of Set 11 | byron bay
# Processing Record 33 of Set 11 | waterford
# Processing Record 34 of Set 11 | laramie
# Processing Record 35 of Set 11 | porto belo
# Processing Record 36 of Set 11 | bella union
# Processing Record 37 of Set 11 | cazones
# Processing Record 38 of Set 11 | lagoa
# Processing Record 39 of Set 11 | lavrentiya
# Processing Record 40 of Set 11 | zlobin
# Processing Record 41 of Set 11 | shakiso
# Processing Record 42 of Set 11 | aksu
# Processing Record 43 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 11 | rabo de peixe
# Processing Record 45 of Set 11 | brae
# Processing Record 46 of Set 11 | altamira
# Processing Record 47 of Set 11 | luderitz
# Processing Record 48 of Set 11 | ahipara
# Processing Record 49 of Set 11 | mareeba
# Processing Record 50 of Set 11 | gboko
# Processing Record 1 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 12 | guerrero negro
# Processing Record 3 of Set 12 | otavi
# Processing Record 4 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 12 | sanlucar la mayor
# Processing Record 6 of Set 12 | sangar
# Processing Record 7 of Set 12 | sitka
# Processing Record 8 of Set 12 | nizip
# Processing Record 9 of Set 12 | jumla
# Processing Record 10 of Set 12 | ahar
# Processing Record 11 of Set 12 | lalin
# Processing Record 12 of Set 12 | port hardy
# Processing Record 13 of Set 12 | havoysund
# Processing Record 14 of Set 12 | marshall
# Processing Record 15 of Set 12 | juliaca
# Processing Record 16 of Set 12 | mongu
# Processing Record 17 of Set 12 | kismayo
# Processing Record 18 of Set 12 | vuktyl
# Processing Record 19 of Set 12 | padang
# Processing Record 20 of Set 12 | jinxiang
# Processing Record 21 of Set 12 | kruisfontein
# Processing Record 22 of Set 12 | kontagora
# Processing Record 23 of Set 12 | asau
# Processing Record 24 of Set 12 | ugoofaaru
# Processing Record 25 of Set 12 | acapulco
# Processing Record 26 of Set 12 | poole
# Processing Record 27 of Set 12 | texarkana
# Processing Record 28 of Set 12 | hoima
# Processing Record 29 of Set 12 | bahir dar
# Processing Record 30 of Set 12 | kirovskiy
# Processing Record 31 of Set 12 | campo gobierno
# Processing Record 32 of Set 12 | labuhan
# Processing Record 33 of Set 12 | canaries
# Processing Record 34 of Set 12 | yinchuan
# Processing Record 35 of Set 12 | koroni
# Processing Record 36 of Set 12 | sobolevo
# Processing Record 37 of Set 12 | xifeng
# Processing Record 38 of Set 12 | trairi
# Processing Record 39 of Set 12 | bairiki
# Processing Record 40 of Set 12 | inhambane
# Processing Record 41 of Set 12 | pundaguitan
# Processing Record 42 of Set 12 | male
# Processing Record 43 of Set 12 | impfondo
# Processing Record 44 of Set 12 | manaus
# Processing Record 45 of Set 12 | seydi
# Processing Record 46 of Set 12 | camana
# Processing Record 47 of Set 12 | springdale
# Processing Record 48 of Set 12 | iskateley
# Processing Record 49 of Set 12 | bundaberg
# Processing Record 50 of Set 12 | erenhot
# Processing Record 1 of Set 13 | nosy varika
# Processing Record 2 of Set 13 | oussouye
# Processing Record 3 of Set 13 | porto santo
# Processing Record 4 of Set 13 | safranbolu
# Processing Record 5 of Set 13 | kuito
# Processing Record 6 of Set 13 | oranjestad
# Processing Record 7 of Set 13 | sao domingos do maranhao
# Processing Record 8 of Set 13 | lac du bonnet
# Processing Record 9 of Set 13 | teguise
# Processing Record 10 of Set 13 | bakchar
# Processing Record 11 of Set 13 | shadegan
# Processing Record 12 of Set 13 | santa maria
# Processing Record 13 of Set 13 | ibra
# Processing Record 14 of Set 13 | aklavik
# Processing Record 15 of Set 13 | tyup
# Processing Record 16 of Set 13 | cockburn town
# Processing Record 17 of Set 13 | stepnyak
# Processing Record 18 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 13 | clyde river
# Processing Record 20 of Set 13 | palmas de monte alto
# Processing Record 21 of Set 13 | makakilo city
# Processing Record 22 of Set 13 | sinegorskiy
# Processing Record 23 of Set 13 | staryy nadym
# Processing Record 24 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 25 of Set 13 | yeppoon
# Processing Record 26 of Set 13 | stornoway
# Processing Record 27 of Set 13 | quime
# Processing Record 28 of Set 13 | wonthaggi
# Processing Record 29 of Set 13 | kaeo
# Processing Record 30 of Set 13 | tongren
# Processing Record 31 of Set 13 | iberia
# Processing Record 32 of Set 13 | pahalgam
# Processing Record 33 of Set 13 | armeria
# Processing Record 34 of Set 13 | sorong
# Processing Record 35 of Set 13 | waipawa
# Processing Record 36 of Set 13 | iwanai
# Processing Record 37 of Set 13 | hof
# Processing Record 38 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 13 | port augusta
# Processing Record 40 of Set 13 | alampur
# Processing Record 41 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 13 | bonthe
# Processing Record 43 of Set 13 | lahij
# Processing Record 44 of Set 13 | pavilosta
# Processing Record 45 of Set 13 | tenali
# Processing Record 46 of Set 13 | fort nelson
# Processing Record 47 of Set 13 | biak
# Processing Record 48 of Set 13 | nadym
# Processing Record 49 of Set 13 | boden
# Processing Record 50 of Set 13 | grindavik
# Processing Record 1 of Set 14 | togur
# Processing Record 2 of Set 14 | maraa
# Processing Record 3 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 14 | zunyi
# Processing Record 5 of Set 14 | northam
# Processing Record 6 of Set 14 | myrtle beach
# Processing Record 7 of Set 14 | kraslava
# Processing Record 8 of Set 14 | taikang
# Processing Record 9 of Set 14 | la fria
# Processing Record 10 of Set 14 | sechura
# Processing Record 11 of Set 14 | bedford
# Processing Record 12 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 13 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 14 | novopskov
# Processing Record 15 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 14 | bemidji
# Processing Record 17 of Set 14 | bima
# Processing Record 18 of Set 14 | pinega
# Processing Record 19 of Set 14 | lipari
# Processing Record 20 of Set 14 | buon me thuot
# City not found. Skipping...
# Processing Record 21 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 14 | castelo do piaui
# Processing Record 23 of Set 14 | rangapara
# Processing Record 24 of Set 14 | gazli
# Processing Record 25 of Set 14 | dubbo
# Processing Record 26 of Set 14 | quilmana
# Processing Record 27 of Set 14 | vizinga
# Processing Record 28 of Set 14 | lander
# Processing Record 29 of Set 14 | brigantine
# Processing Record 30 of Set 14 | tiarei
# Processing Record 31 of Set 14 | colac
# Processing Record 32 of Set 14 | waslala
# Processing Record 33 of Set 14 | berbera
# Processing Record 34 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 14 | cururupu
# Processing Record 36 of Set 14 | garowe
# Processing Record 37 of Set 14 | murdochville
# Processing Record 38 of Set 14 | basco
# Processing Record 39 of Set 14 | sept-iles
# Processing Record 40 of Set 14 | los llanos de aridane
# Processing Record 41 of Set 14 | campos altos
# Processing Record 42 of Set 14 | ambulu
# Processing Record 43 of Set 14 | xapuri
# Processing Record 44 of Set 14 | cumbal
# Processing Record 45 of Set 14 | lata
# Processing Record 46 of Set 14 | woodstock
# Processing Record 47 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 14 | moerai
# Processing Record 49 of Set 14 | ankazoabo
# Processing Record 50 of Set 14 | boa vista
# Processing Record 1 of Set 15 | maracaibo
# Processing Record 2 of Set 15 | shingu
# Processing Record 3 of Set 15 | halifax
# Processing Record 4 of Set 15 | altay
# Processing Record 5 of Set 15 | phan thiet
# Processing Record 6 of Set 15 | guaratinga
# Processing Record 7 of Set 15 | rypefjord
# Processing Record 8 of Set 15 | winsum
# Processing Record 9 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 10 of Set 15 | akyab
# Processing Record 11 of Set 15 | balikpapan
# Processing Record 12 of Set 15 | truth or consequences
# Processing Record 13 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 15 | mecca
# Processing Record 15 of Set 15 | biryusinsk
# Processing Record 16 of Set 15 | kampot
# Processing Record 17 of Set 15 | vestmannaeyjar
# Processing Record 18 of Set 15 | port said
# Processing Record 19 of Set 15 | kidal
# Processing Record 20 of Set 15 | vacha
# Processing Record 21 of Set 15 | gigmoto
# Processing Record 22 of Set 15 | vila franca do campo
# Processing Record 23 of Set 15 | san ramon de la nueva oran
# Processing Record 24 of Set 15 | salinopolis
# Processing Record 25 of Set 15 | bossangoa
# Processing Record 26 of Set 15 | bayir
# Processing Record 27 of Set 15 | whitianga
# Processing Record 28 of Set 15 | galle
# Processing Record 29 of Set 15 | agua verde
# Processing Record 30 of Set 15 | timmins
# Processing Record 31 of Set 15 | melbu
# Processing Record 32 of Set 15 | santa rosalia
# Processing Record 33 of Set 15 | oistins
# Processing Record 34 of Set 15 | ranong
# Processing Record 35 of Set 15 | kimbe
# Processing Record 36 of Set 15 | yeehaw junction
# City not found. Skipping...
# Processing Record 37 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 38 of Set 15 | tambopata
# Processing Record 39 of Set 15 | itoman
# Processing Record 40 of Set 15 | jacobina
# Processing Record 41 of Set 15 | puerto narino
# Processing Record 42 of Set 15 | tezu
# Processing Record 43 of Set 15 | bulgan
# Processing Record 44 of Set 15 | jijiang
# Processing Record 45 of Set 15 | kazuno
# Processing Record 46 of Set 15 | pitimbu
# Processing Record 47 of Set 15 | pitea
# Processing Record 48 of Set 15 | burns lake
# Processing Record 49 of Set 15 | nemuro
# Processing Record 50 of Set 15 | san andres
# Processing Record 1 of Set 16 | vila do maio
# Processing Record 2 of Set 16 | cap malheureux
# Processing Record 3 of Set 16 | juneau
# Processing Record 4 of Set 16 | sisophon
# Processing Record 5 of Set 16 | zaraza
# Processing Record 6 of Set 16 | yenagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia -54.8000  -68.3000     48.20        53          75
# 1          Rikitea -23.1203 -134.9692     74.50        61          14
# 2  Haines Junction  60.7522 -137.5108     46.40        71         100
# 3         Benghazi  32.1167   20.0667     72.66        41           0
# 4         Khatanga  71.9667  102.5000     22.69        81         100
# 5           Hobart -42.8794  147.3294     62.60        48          20
# 6            Vaini -21.2000 -175.2000     78.80        89          40
# 7           Albany  42.6001  -73.9662     57.00        77          44
# 8       Nikolskoye  59.7035   30.7861     61.00        94          40
# 9           Dikson  73.5069   80.5464     23.18        88          95
#
#    Wind Speed Country Current Description
# 0        9.22      AR          light rain
# 1        8.41      PF          few clouds
# 2        8.05      CA          light rain
# 3        5.82      LY           clear sky
# 4       13.35      RU     overcast clouds
# 5       18.41      AU          few clouds
# 6        5.75      TO    scattered clouds
# 7        3.02      US    scattered clouds
# 8        4.47      RU                 fog
# 9        5.44      RU     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     48.20        53          75
# 1          Rikitea      PF -23.1203 -134.9692     74.50        61          14
# 2  Haines Junction      CA  60.7522 -137.5108     46.40        71         100
# 3         Benghazi      LY  32.1167   20.0667     72.66        41           0
# 4         Khatanga      RU  71.9667  102.5000     22.69        81         100
# 5           Hobart      AU -42.8794  147.3294     62.60        48          20
# 6            Vaini      TO -21.2000 -175.2000     78.80        89          40
# 7           Albany      US  42.6001  -73.9662     57.00        77          44
# 8       Nikolskoye      RU  59.7035   30.7861     61.00        94          40
# 9           Dikson      RU  73.5069   80.5464     23.18        88          95
#
#    Wind Speed Current Description
# 0        9.22          light rain
# 1        8.41          few clouds
# 2        8.05          light rain
# 3        5.82           clear sky
# 4       13.35     overcast clouds
# 5       18.41          few clouds
# 6        5.75    scattered clouds
# 7        3.02    scattered clouds
# 8        4.47                 fog
# 9        5.44     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
