# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | isangel
# Processing Record 6 of Set 1 | lucapa
# Processing Record 7 of Set 1 | tautira
# Processing Record 8 of Set 1 | pasco
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | nsanje
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | pontianak
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | ocos
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | kavieng
# Processing Record 24 of Set 1 | manvi
# Processing Record 25 of Set 1 | makow mazowiecki
# Processing Record 26 of Set 1 | olawa
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | xuddur
# Processing Record 29 of Set 1 | qinhuangdao
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 33 of Set 1 | mehamn
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | dubbo
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | pangai
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | tigil
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | honiara
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | port blair
# Processing Record 3 of Set 2 | bethel
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | astanajapura
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | beaverlodge
# Processing Record 10 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 2 | vila velha
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | changtu
# Processing Record 16 of Set 2 | provideniya
# Processing Record 17 of Set 2 | muros
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | keetmanshoop
# Processing Record 21 of Set 2 | toppenish
# Processing Record 22 of Set 2 | meulaboh
# Processing Record 23 of Set 2 | port moresby
# Processing Record 24 of Set 2 | biu
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | esperance
# Processing Record 28 of Set 2 | baykit
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | graham
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | juli
# Processing Record 36 of Set 2 | boden
# Processing Record 37 of Set 2 | jaciara
# Processing Record 38 of Set 2 | chimbote
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | baloda
# Processing Record 41 of Set 2 | ontario
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | vestmannaeyjar
# Processing Record 44 of Set 2 | mount isa
# Processing Record 45 of Set 2 | humaita
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | antofagasta
# Processing Record 48 of Set 2 | mukerian
# Processing Record 49 of Set 2 | north bend
# Processing Record 50 of Set 2 | obo
# Processing Record 1 of Set 3 | waingapu
# Processing Record 2 of Set 3 | puerto ayora
# Processing Record 3 of Set 3 | charters towers
# Processing Record 4 of Set 3 | damietta
# Processing Record 5 of Set 3 | te anau
# Processing Record 6 of Set 3 | mumford
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | morinville
# Processing Record 9 of Set 3 | mahebourg
# Processing Record 10 of Set 3 | maniitsoq
# Processing Record 11 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 3 | grindavik
# Processing Record 13 of Set 3 | kibala
# Processing Record 14 of Set 3 | beidao
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 17 of Set 3 | nuuk
# Processing Record 18 of Set 3 | cravo norte
# Processing Record 19 of Set 3 | ankazoabo
# Processing Record 20 of Set 3 | jubayl
# City not found. Skipping...
# Processing Record 21 of Set 3 | luderitz
# Processing Record 22 of Set 3 | lavrentiya
# Processing Record 23 of Set 3 | jacareacanga
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 3 | ust-tarka
# Processing Record 27 of Set 3 | goya
# Processing Record 28 of Set 3 | saint-augustin
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | muzaffarabad
# Processing Record 33 of Set 3 | itarema
# Processing Record 34 of Set 3 | dicabisagan
# Processing Record 35 of Set 3 | sakakah
# Processing Record 36 of Set 3 | san ramon
# Processing Record 37 of Set 3 | pennagaram
# Processing Record 38 of Set 3 | baherden
# Processing Record 39 of Set 3 | hit
# Processing Record 40 of Set 3 | camden
# Processing Record 41 of Set 3 | kahului
# Processing Record 42 of Set 3 | muswellbrook
# Processing Record 43 of Set 3 | mecca
# Processing Record 44 of Set 3 | karwar
# Processing Record 45 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 3 | moron
# Processing Record 47 of Set 3 | hovd
# Processing Record 48 of Set 3 | fort nelson
# Processing Record 49 of Set 3 | mandla
# Processing Record 50 of Set 3 | wasilla
# Processing Record 1 of Set 4 | shingu
# Processing Record 2 of Set 4 | gamba
# Processing Record 3 of Set 4 | vardo
# Processing Record 4 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 4 | busselton
# Processing Record 6 of Set 4 | stephenville
# Processing Record 7 of Set 4 | cherdyn
# Processing Record 8 of Set 4 | haines junction
# Processing Record 9 of Set 4 | xining
# Processing Record 10 of Set 4 | seoul
# Processing Record 11 of Set 4 | geraldton
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | labuan
# Processing Record 14 of Set 4 | berlevag
# Processing Record 15 of Set 4 | thompson
# Processing Record 16 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 4 | pontal do parana
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | rocha
# Processing Record 21 of Set 4 | port macquarie
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | tshikapa
# Processing Record 24 of Set 4 | idar-oberstein
# Processing Record 25 of Set 4 | east wenatchee bench
# Processing Record 26 of Set 4 | pahrump
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | terrace bay
# Processing Record 30 of Set 4 | lichtenburg
# Processing Record 31 of Set 4 | mackay
# Processing Record 32 of Set 4 | behbahan
# Processing Record 33 of Set 4 | talavera
# Processing Record 34 of Set 4 | tual
# Processing Record 35 of Set 4 | shangrao
# Processing Record 36 of Set 4 | leningradskiy
# Processing Record 37 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of Set 4 | harboore
# Processing Record 39 of Set 4 | saint-georges
# Processing Record 40 of Set 4 | pasir gudang
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | castro
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 4 | beypur
# City not found. Skipping...
# Processing Record 46 of Set 4 | mahibadhoo
# Processing Record 47 of Set 4 | tyulgan
# Processing Record 48 of Set 4 | tilichiki
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | etzatlan
# Processing Record 1 of Set 5 | cherskiy
# Processing Record 2 of Set 5 | henties bay
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | ust-kuyga
# Processing Record 6 of Set 5 | kostroma
# Processing Record 7 of Set 5 | shenkursk
# Processing Record 8 of Set 5 | noumea
# Processing Record 9 of Set 5 | hilo
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | san lawrenz
# Processing Record 12 of Set 5 | marsaxlokk
# Processing Record 13 of Set 5 | yumen
# Processing Record 14 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 5 | burica
# City not found. Skipping...
# Processing Record 16 of Set 5 | banjarmasin
# Processing Record 17 of Set 5 | quatre cocos
# Processing Record 18 of Set 5 | storforshei
# Processing Record 19 of Set 5 | envira
# Processing Record 20 of Set 5 | corinto
# Processing Record 21 of Set 5 | vaitape
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | porto novo
# Processing Record 24 of Set 5 | klaksvik
# Processing Record 25 of Set 5 | tura
# Processing Record 26 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 5 | orlik
# Processing Record 28 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 5 | kloulklubed
# Processing Record 30 of Set 5 | yatou
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | sosnogorsk
# Processing Record 33 of Set 5 | vuktyl
# Processing Record 34 of Set 5 | saskylakh
# Processing Record 35 of Set 5 | majene
# Processing Record 36 of Set 5 | mayo
# Processing Record 37 of Set 5 | raudeberg
# Processing Record 38 of Set 5 | uruzgan
# Processing Record 39 of Set 5 | price
# Processing Record 40 of Set 5 | astoria
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | pangnirtung
# Processing Record 43 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | longyearbyen
# Processing Record 46 of Set 5 | buala
# Processing Record 47 of Set 5 | charleston
# Processing Record 48 of Set 5 | kharan
# Processing Record 49 of Set 5 | mago
# Processing Record 50 of Set 5 | cap malheureux
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | hay river
# Processing Record 3 of Set 6 | vangaindrano
# Processing Record 4 of Set 6 | zaysan
# Processing Record 5 of Set 6 | abha
# Processing Record 6 of Set 6 | banda aceh
# Processing Record 7 of Set 6 | raglan
# Processing Record 8 of Set 6 | kuryk
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | iberia
# Processing Record 11 of Set 6 | matara
# Processing Record 12 of Set 6 | mapimi
# Processing Record 13 of Set 6 | helena
# Processing Record 14 of Set 6 | shiloh
# Processing Record 15 of Set 6 | sao filipe
# Processing Record 16 of Set 6 | lasa
# Processing Record 17 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 6 | kudahuvadhoo
# Processing Record 19 of Set 6 | bhadrachalam
# Processing Record 20 of Set 6 | katsuura
# Processing Record 21 of Set 6 | kropotkin
# Processing Record 22 of Set 6 | presidencia roque saenz pena
# Processing Record 23 of Set 6 | hualmay
# Processing Record 24 of Set 6 | faanui
# Processing Record 25 of Set 6 | tangshan
# Processing Record 26 of Set 6 | novoilinsk
# Processing Record 27 of Set 6 | poum
# Processing Record 28 of Set 6 | scottsbluff
# Processing Record 29 of Set 6 | khomeyn
# Processing Record 30 of Set 6 | paciran
# Processing Record 31 of Set 6 | bonthe
# Processing Record 32 of Set 6 | nouadhibou
# Processing Record 33 of Set 6 | puerto escondido
# Processing Record 34 of Set 6 | ukiah
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | kununurra
# Processing Record 37 of Set 6 | araouane
# Processing Record 38 of Set 6 | itacoatiara
# Processing Record 39 of Set 6 | taltal
# Processing Record 40 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 41 of Set 6 | cangzhou
# Processing Record 42 of Set 6 | hammerfest
# Processing Record 43 of Set 6 | coahuayana
# Processing Record 44 of Set 6 | umm lajj
# Processing Record 45 of Set 6 | wazzan
# City not found. Skipping...
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | aksu
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | ahipara
# Processing Record 50 of Set 6 | havelock
# Processing Record 1 of Set 7 | byron bay
# Processing Record 2 of Set 7 | edson
# Processing Record 3 of Set 7 | omsukchan
# Processing Record 4 of Set 7 | ramon
# Processing Record 5 of Set 7 | sturovo
# Processing Record 6 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 7 | anadyr
# Processing Record 8 of Set 7 | gayny
# Processing Record 9 of Set 7 | palauig
# Processing Record 10 of Set 7 | chuy
# Processing Record 11 of Set 7 | samarkand
# Processing Record 12 of Set 7 | alice springs
# Processing Record 13 of Set 7 | ayorou
# Processing Record 14 of Set 7 | port-gentil
# Processing Record 15 of Set 7 | lompoc
# Processing Record 16 of Set 7 | grand gaube
# Processing Record 17 of Set 7 | na klang
# Processing Record 18 of Set 7 | griffith
# Processing Record 19 of Set 7 | santa marta
# Processing Record 20 of Set 7 | dingle
# Processing Record 21 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 7 | bangkal
# Processing Record 23 of Set 7 | kasongo-lunda
# Processing Record 24 of Set 7 | indramayu
# Processing Record 25 of Set 7 | chipiona
# Processing Record 26 of Set 7 | cidreira
# Processing Record 27 of Set 7 | arys
# Processing Record 28 of Set 7 | nanortalik
# Processing Record 29 of Set 7 | wanning
# Processing Record 30 of Set 7 | chitral
# Processing Record 31 of Set 7 | pisco
# Processing Record 32 of Set 7 | vilhena
# Processing Record 33 of Set 7 | tazovskiy
# Processing Record 34 of Set 7 | semey
# Processing Record 35 of Set 7 | nargana
# Processing Record 36 of Set 7 | malambo
# Processing Record 37 of Set 7 | bilibino
# Processing Record 38 of Set 7 | grants pass
# Processing Record 39 of Set 7 | bairiki
# Processing Record 40 of Set 7 | sangueya
# Processing Record 41 of Set 7 | assare
# Processing Record 42 of Set 7 | vao
# Processing Record 43 of Set 7 | tokoroa
# Processing Record 44 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 7 | gbarnga
# Processing Record 46 of Set 7 | coihaique
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | polovinnoye
# Processing Record 49 of Set 7 | smithers
# Processing Record 50 of Set 7 | kerman
# Processing Record 1 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 8 | severo-kurilsk
# Processing Record 3 of Set 8 | sokoni
# Processing Record 4 of Set 8 | poya
# Processing Record 5 of Set 8 | lorengau
# Processing Record 6 of Set 8 | sambava
# Processing Record 7 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 8 of Set 8 | barcelos
# Processing Record 9 of Set 8 | blonduos
# City not found. Skipping...
# Processing Record 10 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 8 | eirunepe
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | gao
# Processing Record 14 of Set 8 | sisimiut
# Processing Record 15 of Set 8 | bonnyville
# Processing Record 16 of Set 8 | boyabat
# Processing Record 17 of Set 8 | arroyo
# Processing Record 18 of Set 8 | yar-sale
# Processing Record 19 of Set 8 | sainte-maxime
# Processing Record 20 of Set 8 | dalvik
# Processing Record 21 of Set 8 | kyra
# Processing Record 22 of Set 8 | gimli
# Processing Record 23 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 8 | sarmellek
# Processing Record 25 of Set 8 | pangody
# Processing Record 26 of Set 8 | takoradi
# Processing Record 27 of Set 8 | peace river
# Processing Record 28 of Set 8 | gizo
# Processing Record 29 of Set 8 | yanam
# Processing Record 30 of Set 8 | magaria
# Processing Record 31 of Set 8 | zhuhai
# Processing Record 32 of Set 8 | kontagora
# Processing Record 33 of Set 8 | san pedro
# Processing Record 34 of Set 8 | lisakovsk
# Processing Record 35 of Set 8 | disna
# Processing Record 36 of Set 8 | saint anthony
# Processing Record 37 of Set 8 | lokosovo
# Processing Record 38 of Set 8 | portree
# Processing Record 39 of Set 8 | ossora
# Processing Record 40 of Set 8 | hami
# Processing Record 41 of Set 8 | qaanaaq
# Processing Record 42 of Set 8 | clyde river
# Processing Record 43 of Set 8 | constitucion
# Processing Record 44 of Set 8 | ayagoz
# Processing Record 45 of Set 8 | troitsko-pechorsk
# Processing Record 46 of Set 8 | pacific grove
# Processing Record 47 of Set 8 | vrangel
# Processing Record 48 of Set 8 | sabinopolis
# Processing Record 49 of Set 8 | san policarpo
# Processing Record 50 of Set 8 | altay
# Processing Record 1 of Set 9 | srednekolymsk
# Processing Record 2 of Set 9 | riohacha
# Processing Record 3 of Set 9 | marsa matruh
# Processing Record 4 of Set 9 | guasdualito
# Processing Record 5 of Set 9 | kenai
# Processing Record 6 of Set 9 | pasighat
# Processing Record 7 of Set 9 | egvekinot
# Processing Record 8 of Set 9 | prince george
# Processing Record 9 of Set 9 | sinnamary
# Processing Record 10 of Set 9 | kargasok
# Processing Record 11 of Set 9 | monte alegre
# Processing Record 12 of Set 9 | hurricane
# Processing Record 13 of Set 9 | auki
# Processing Record 14 of Set 9 | praia da vitoria
# Processing Record 15 of Set 9 | acari
# Processing Record 16 of Set 9 | narsaq
# Processing Record 17 of Set 9 | nichinan
# Processing Record 18 of Set 9 | merauke
# Processing Record 19 of Set 9 | sadovoye
# Processing Record 20 of Set 9 | dalbandin
# Processing Record 21 of Set 9 | yerbogachen
# Processing Record 22 of Set 9 | pascagoula
# Processing Record 23 of Set 9 | tessalit
# Processing Record 24 of Set 9 | canandaigua
# Processing Record 25 of Set 9 | konevo
# Processing Record 26 of Set 9 | biltine
# Processing Record 27 of Set 9 | flagstaff
# Processing Record 28 of Set 9 | caracuaro
# Processing Record 29 of Set 9 | bekobod
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | edd
# Processing Record 32 of Set 9 | viedma
# Processing Record 33 of Set 9 | jiwani
# Processing Record 34 of Set 9 | upernavik
# Processing Record 35 of Set 9 | talara
# Processing Record 36 of Set 9 | jinchang
# Processing Record 37 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 9 | saldanha
# Processing Record 39 of Set 9 | kuito
# Processing Record 40 of Set 9 | ostrovnoy
# Processing Record 41 of Set 9 | port lincoln
# Processing Record 42 of Set 9 | guerrero negro
# Processing Record 43 of Set 9 | horta
# Processing Record 44 of Set 9 | lakselv
# Processing Record 45 of Set 9 | hambantota
# Processing Record 46 of Set 9 | naze
# Processing Record 47 of Set 9 | novoagansk
# Processing Record 48 of Set 9 | nemuro
# Processing Record 49 of Set 9 | inyonga
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | ca mau
# Processing Record 2 of Set 10 | lincoln
# Processing Record 3 of Set 10 | qingdao
# Processing Record 4 of Set 10 | mpongwe
# Processing Record 5 of Set 10 | chunskiy
# Processing Record 6 of Set 10 | lerwick
# Processing Record 7 of Set 10 | rio gallegos
# Processing Record 8 of Set 10 | camacari
# Processing Record 9 of Set 10 | blagoveshchensk
# Processing Record 10 of Set 10 | tiznit
# Processing Record 11 of Set 10 | wajima
# Processing Record 12 of Set 10 | dekoa
# City not found. Skipping...
# Processing Record 13 of Set 10 | sosva
# Processing Record 14 of Set 10 | hede
# Processing Record 15 of Set 10 | khandbari
# Processing Record 16 of Set 10 | ahuimanu
# Processing Record 17 of Set 10 | labuhan
# Processing Record 18 of Set 10 | hopkinsville
# Processing Record 19 of Set 10 | udachnyy
# Processing Record 20 of Set 10 | victor harbor
# Processing Record 21 of Set 10 | along
# Processing Record 22 of Set 10 | salalah
# Processing Record 23 of Set 10 | coaticook
# Processing Record 24 of Set 10 | azare
# Processing Record 25 of Set 10 | gambela
# Processing Record 26 of Set 10 | chahuites
# Processing Record 27 of Set 10 | sheboygan
# Processing Record 28 of Set 10 | zhezkazgan
# Processing Record 29 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 10 | syracuse
# Processing Record 31 of Set 10 | agadez
# Processing Record 32 of Set 10 | sidi ali
# Processing Record 33 of Set 10 | nola
# Processing Record 34 of Set 10 | bhavnagar
# Processing Record 35 of Set 10 | chokwe
# Processing Record 36 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 37 of Set 10 | bayan
# Processing Record 38 of Set 10 | shenxian
# Processing Record 39 of Set 10 | half moon bay
# Processing Record 40 of Set 10 | caxito
# Processing Record 41 of Set 10 | laug
# Processing Record 42 of Set 10 | chaibasa
# Processing Record 43 of Set 10 | custoias
# Processing Record 44 of Set 10 | klyuchi
# Processing Record 45 of Set 10 | jalu
# Processing Record 46 of Set 10 | marawi
# Processing Record 47 of Set 10 | bereda
# Processing Record 48 of Set 10 | sept-iles
# Processing Record 49 of Set 10 | sivaki
# Processing Record 50 of Set 10 | ixtapa
# Processing Record 1 of Set 11 | san carlos del zulia
# Processing Record 2 of Set 11 | tiksi
# Processing Record 3 of Set 11 | candido mendes
# Processing Record 4 of Set 11 | alta floresta
# Processing Record 5 of Set 11 | dakar
# Processing Record 6 of Set 11 | puerto baquerizo moreno
# Processing Record 7 of Set 11 | yulara
# Processing Record 8 of Set 11 | toora-khem
# Processing Record 9 of Set 11 | vila do maio
# Processing Record 10 of Set 11 | sile
# Processing Record 11 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 11 | chupa
# Processing Record 13 of Set 11 | salym
# Processing Record 14 of Set 11 | aykhal
# Processing Record 15 of Set 11 | chapais
# Processing Record 16 of Set 11 | bartica
# Processing Record 17 of Set 11 | lugus
# Processing Record 18 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 11 | sheregesh
# Processing Record 20 of Set 11 | boa vista
# Processing Record 21 of Set 11 | parrita
# Processing Record 22 of Set 11 | gunjur
# Processing Record 23 of Set 11 | ozinki
# Processing Record 24 of Set 11 | northam
# Processing Record 25 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 11 | boiu mare
# Processing Record 27 of Set 11 | christchurch
# Processing Record 28 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 11 | shabrovskiy
# Processing Record 30 of Set 11 | maamba
# Processing Record 31 of Set 11 | north platte
# Processing Record 32 of Set 11 | hue
# Processing Record 33 of Set 11 | esmeralda
# Processing Record 34 of Set 11 | kantemirovka
# Processing Record 35 of Set 11 | murmashi
# Processing Record 36 of Set 11 | lukh
# Processing Record 37 of Set 11 | san juan
# Processing Record 38 of Set 11 | shetpe
# Processing Record 39 of Set 11 | tamiahua
# Processing Record 40 of Set 11 | calvinia
# Processing Record 41 of Set 11 | monrovia
# Processing Record 42 of Set 11 | cayenne
# Processing Record 43 of Set 11 | arlit
# Processing Record 44 of Set 11 | broome
# Processing Record 45 of Set 11 | bethanien
# Processing Record 46 of Set 11 | kiunga
# Processing Record 47 of Set 11 | kayasula
# Processing Record 48 of Set 11 | mogocha
# Processing Record 49 of Set 11 | madison
# Processing Record 50 of Set 11 | pokhara
# Processing Record 1 of Set 12 | jasdan
# Processing Record 2 of Set 12 | lunel
# Processing Record 3 of Set 12 | siofok
# Processing Record 4 of Set 12 | praia
# Processing Record 5 of Set 12 | muroto
# Processing Record 6 of Set 12 | iskateley
# Processing Record 7 of Set 12 | chernyshevskiy
# Processing Record 8 of Set 12 | buchmany
# Processing Record 9 of Set 12 | saint-francois
# Processing Record 10 of Set 12 | kupang
# Processing Record 11 of Set 12 | kuusamo
# Processing Record 12 of Set 12 | nkhotakota
# Processing Record 13 of Set 12 | garowe
# Processing Record 14 of Set 12 | poltavka
# Processing Record 15 of Set 12 | pevek
# Processing Record 16 of Set 12 | pangkalanbuun
# Processing Record 17 of Set 12 | zlocieniec
# Processing Record 18 of Set 12 | sattur
# Processing Record 19 of Set 12 | okhotsk
# Processing Record 20 of Set 12 | kabalo
# Processing Record 21 of Set 12 | sokoto
# Processing Record 22 of Set 12 | plettenberg bay
# Processing Record 23 of Set 12 | luancheng
# Processing Record 24 of Set 12 | progreso
# Processing Record 25 of Set 12 | yenagoa
# Processing Record 26 of Set 12 | kavaratti
# Processing Record 27 of Set 12 | ximei
# Processing Record 28 of Set 12 | madridejos
# Processing Record 29 of Set 12 | baruun-urt
# Processing Record 30 of Set 12 | kushima
# Processing Record 31 of Set 12 | acarau
# Processing Record 32 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 34 of Set 12 | champerico
# Processing Record 35 of Set 12 | harper
# Processing Record 36 of Set 12 | moussoro
# Processing Record 37 of Set 12 | panama city
# Processing Record 38 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 39 of Set 12 | hobyo
# Processing Record 40 of Set 12 | nayoro
# Processing Record 41 of Set 12 | ashland
# Processing Record 42 of Set 12 | yoichi
# Processing Record 43 of Set 12 | petatlan
# Processing Record 44 of Set 12 | benguela
# Processing Record 45 of Set 12 | carballo
# Processing Record 46 of Set 12 | eureka
# Processing Record 47 of Set 12 | fortuna
# Processing Record 48 of Set 12 | beloha
# Processing Record 49 of Set 12 | mogadishu
# Processing Record 50 of Set 12 | gorontalo
# Processing Record 1 of Set 13 | songjianghe
# Processing Record 2 of Set 13 | mangrol
# Processing Record 3 of Set 13 | gobabis
# Processing Record 4 of Set 13 | dawei
# Processing Record 5 of Set 13 | monastyrshchina
# Processing Record 6 of Set 13 | tungor
# Processing Record 7 of Set 13 | san borja
# Processing Record 8 of Set 13 | mitha tiwana
# Processing Record 9 of Set 13 | teahupoo
# Processing Record 10 of Set 13 | walla walla
# Processing Record 11 of Set 13 | komsomolskiy
# Processing Record 12 of Set 13 | khatanga
# Processing Record 13 of Set 13 | kintampo
# Processing Record 14 of Set 13 | paita
# Processing Record 15 of Set 13 | tari
# Processing Record 16 of Set 13 | tukrah
# Processing Record 17 of Set 13 | shimoda
# Processing Record 18 of Set 13 | wainwright
# Processing Record 19 of Set 13 | bontang
# Processing Record 20 of Set 13 | camabatela
# Processing Record 21 of Set 13 | bolshoye selo
# Processing Record 22 of Set 13 | pimentel
# Processing Record 23 of Set 13 | college
# Processing Record 24 of Set 13 | altona
# Processing Record 25 of Set 13 | thunder bay
# Processing Record 26 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 13 | rafsanjan
# Processing Record 28 of Set 13 | ushtobe
# Processing Record 29 of Set 13 | sawakin
# Processing Record 30 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 31 of Set 13 | shar
# Processing Record 32 of Set 13 | trinidad
# Processing Record 33 of Set 13 | hervey bay
# Processing Record 34 of Set 13 | biak
# Processing Record 35 of Set 13 | olafsvik
# Processing Record 36 of Set 13 | zainsk
# Processing Record 37 of Set 13 | ibotirama
# Processing Record 38 of Set 13 | windhoek
# Processing Record 39 of Set 13 | manadhoo
# Processing Record 40 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 13 | atambua
# Processing Record 42 of Set 13 | ulladulla
# Processing Record 43 of Set 13 | zuenoula
# Processing Record 44 of Set 13 | natal
# Processing Record 45 of Set 13 | le port
# Processing Record 46 of Set 13 | karratha
# Processing Record 47 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 48 of Set 13 | portland
# Processing Record 49 of Set 13 | morondava
# Processing Record 50 of Set 13 | camocim
# Processing Record 1 of Set 14 | dhidhdhoo
# Processing Record 2 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 3 of Set 14 | fayaoue
# Processing Record 4 of Set 14 | tecpan
# Processing Record 5 of Set 14 | darnah
# Processing Record 6 of Set 14 | malanje
# Processing Record 7 of Set 14 | chitipa
# Processing Record 8 of Set 14 | atar
# Processing Record 9 of Set 14 | sabang
# Processing Record 10 of Set 14 | muret
# Processing Record 11 of Set 14 | torokszentmiklos
# Processing Record 12 of Set 14 | strezhevoy
# Processing Record 13 of Set 14 | fenyi
# Processing Record 14 of Set 14 | conde
# Processing Record 15 of Set 14 | hwange
# Processing Record 16 of Set 14 | kopychyntsi
# Processing Record 17 of Set 14 | port-cartier
# Processing Record 18 of Set 14 | teya
# Processing Record 19 of Set 14 | farafangana
# Processing Record 20 of Set 14 | tommot
# Processing Record 21 of Set 14 | karpogory
# Processing Record 22 of Set 14 | korla
# Processing Record 23 of Set 14 | port hueneme
# Processing Record 24 of Set 14 | natchez
# Processing Record 25 of Set 14 | nelson bay
# Processing Record 26 of Set 14 | igrim
# Processing Record 27 of Set 14 | bandarbeyla
# Processing Record 28 of Set 14 | erzin
# Processing Record 29 of Set 14 | walker
# Processing Record 30 of Set 14 | panguna
# Processing Record 31 of Set 14 | luau
# Processing Record 32 of Set 14 | benghazi
# Processing Record 33 of Set 14 | margate
# Processing Record 34 of Set 14 | luwero
# Processing Record 35 of Set 14 | tsogni
# Processing Record 36 of Set 14 | zyryanka
# Processing Record 37 of Set 14 | general roca
# Processing Record 38 of Set 14 | avera
# Processing Record 39 of Set 14 | kingseat
# Processing Record 40 of Set 14 | ostersund
# Processing Record 41 of Set 14 | vanavara
# Processing Record 42 of Set 14 | qui nhon
# Processing Record 43 of Set 14 | richards bay
# Processing Record 44 of Set 14 | conakry
# Processing Record 45 of Set 14 | samfya
# Processing Record 46 of Set 14 | wyndham
# Processing Record 47 of Set 14 | gigant
# Processing Record 48 of Set 14 | namibe
# Processing Record 49 of Set 14 | ugoofaaru
# Processing Record 50 of Set 14 | sabya
# Processing Record 1 of Set 15 | iralaya
# Processing Record 2 of Set 15 | belyy yar
# Processing Record 3 of Set 15 | puerto narino
# Processing Record 4 of Set 15 | mount pleasant
# Processing Record 5 of Set 15 | bud
# Processing Record 6 of Set 15 | vanimo
# Processing Record 7 of Set 15 | lazaro cardenas
# Processing Record 8 of Set 15 | quelimane
# Processing Record 9 of Set 15 | molina
# Processing Record 10 of Set 15 | kpandae
# Processing Record 11 of Set 15 | adrar
# Processing Record 12 of Set 15 | jiangyou
# Processing Record 13 of Set 15 | lodja
# Processing Record 14 of Set 15 | manasa
# Processing Record 15 of Set 15 | gari
# Processing Record 16 of Set 15 | aswan
# Processing Record 17 of Set 15 | launceston
# Processing Record 18 of Set 15 | kabelvag
# Processing Record 19 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 15 | indian head
# Processing Record 23 of Set 15 | acapulco
# Processing Record 24 of Set 15 | rongcheng
# Processing Record 25 of Set 15 | belinskiy
# Processing Record 26 of Set 15 | ulaanbaatar
# Processing Record 27 of Set 15 | katobu
# Processing Record 28 of Set 15 | talaya
# Processing Record 29 of Set 15 | lubango
# Processing Record 30 of Set 15 | ginda
# Processing Record 31 of Set 15 | port said
# Processing Record 32 of Set 15 | kholodnyy
# Processing Record 33 of Set 15 | aitape
# Processing Record 34 of Set 15 | melo
# Processing Record 35 of Set 15 | opuwo
# Processing Record 36 of Set 15 | pochutla
# Processing Record 37 of Set 15 | hohhot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas -53.1500  -70.9167     44.60        87          90
# 1  Arraial Do Cabo -22.9661  -42.0278     66.20        94          40
# 2           Atuona  -9.8000 -139.0333     79.20        71          63
# 3          Isangel -19.5500  169.2667     77.00        88          90
# 4           Lucapa  -8.4192   20.7447     83.97        35          42
# 5          Tautira -17.7333 -149.1500     78.01        83           0
# 6            Pasco  28.2920  -82.4165     64.00        82          94
# 7   Port Elizabeth -33.9180   25.5701     64.40        52           0
# 8           Nsanje -16.9200   35.2620     96.19        24           0
# 9           Barrow  71.2906 -156.7887     26.60        86          90
#
#    Wind Speed Country Current Description
# 0       19.57      CL     overcast clouds
# 1        2.30      BR    scattered clouds
# 2       13.51      PF       broken clouds
# 3       11.34      VU     overcast clouds
# 4        6.91      AO    scattered clouds
# 5        3.44      PF          light rain
# 6        7.18      US     overcast clouds
# 7       20.71      ZA           clear sky
# 8        2.75      MW           clear sky
# 9        9.22      US          light snow

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Punta Arenas      CL -53.1500  -70.9167     44.60        87          90
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     66.20        94          40
# 2           Atuona      PF  -9.8000 -139.0333     79.20        71          63
# 3          Isangel      VU -19.5500  169.2667     77.00        88          90
# 4           Lucapa      AO  -8.4192   20.7447     83.97        35          42
# 5          Tautira      PF -17.7333 -149.1500     78.01        83           0
# 6            Pasco      US  28.2920  -82.4165     64.00        82          94
# 7   Port Elizabeth      ZA -33.9180   25.5701     64.40        52           0
# 8           Nsanje      MW -16.9200   35.2620     96.19        24           0
# 9           Barrow      US  71.2906 -156.7887     26.60        86          90
#
#    Wind Speed Current Description
# 0       19.57     overcast clouds
# 1        2.30    scattered clouds
# 2       13.51       broken clouds
# 3       11.34     overcast clouds
# 4        6.91    scattered clouds
# 5        3.44          light rain
# 6        7.18     overcast clouds
# 7       20.71           clear sky
# 8        2.75           clear sky
# 9        9.22          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
